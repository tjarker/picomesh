# %%
accDelay = [174, 165, 177, 168, 180, 162, 195, 177, 210, 192]
avgDelay = [9.666666666666666, 9.166666666666666, 9.833333333333334, 9.333333333333334, 10.0, 9.0, 10.833333333333334, 9.833333333333334, 11.666666666666666, 10.666666666666666]
maxDelay = [13,12,15,14,15,14,15,14,15,14]

# %%
# create bar plot for avgDelay and maxDelay
import matplotlib.pyplot as plt

x = range(len(avgDelay))
width = 0.35

plt.bar([i - width/2 for i in x], avgDelay, width, label='Average Delay')
plt.bar([i + width/2 for i in x], maxDelay, width, label='Max Delay')

# Highlight the column with the lowest value for each set
min_avg_idx = avgDelay.index(min(avgDelay))
min_max_idx = maxDelay.index(min(maxDelay))

plt.bar([min_avg_idx - width/2], [avgDelay[min_avg_idx]], width, color='green', alpha=0.7, label='Min Avg Delay')
plt.bar([min_max_idx + width/2], [maxDelay[min_max_idx]], width, color='green', alpha=0.7, label='Min Max Delay')

plt.xticks(list(x), [i + 1 for i in x])
plt.xlabel('Index')
plt.ylabel('Delay')
plt.legend()
plt.show()
